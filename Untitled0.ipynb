# %% [markdown]
# <a href="https://colab.research.google.com/github/Gerald-mut/Keras-intro/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np

# %%
dataset = np.loadtxt("pima-indians-diabetes.csv", delimiter=",")

# %%
dataset.shape
# Out:
# (768, 9)

# %%
x = dataset[:,0:8]
y = dataset[:,8]

# %%
x[0]
# Out:
# array([  6.   , 148.   ,  72.   ,  35.   ,   0.   ,  33.6  ,   0.627,
#         50.   ])

# %%
#create model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#compile model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
#fit the model
model.fit(x, y, epochs=15, batch_size=10, verbose=2)
# Out:
# Epoch 1/15
# 77/77 - 1s - 18ms/step - accuracy: 0.5586 - loss: 2.9784
# Epoch 2/15
# 77/77 - 0s - 2ms/step - accuracy: 0.6081 - loss: 1.4233
# Epoch 3/15
# 77/77 - 0s - 2ms/step - accuracy: 0.6328 - loss: 0.9755
# Epoch 4/15
# 77/77 - 0s - 2ms/step - accuracy: 0.6484 - loss: 0.8764
# Epoch 5/15
# 77/77 - 0s - 4ms/step - accuracy: 0.6458 - loss: 0.8047
# Epoch 6/15
# 77/77 - 0s - 3ms/step - accuracy: 0.6341 - loss: 0.7792
# Epoch 7/15
# 77/77 - 0s - 3ms/step - accuracy: 0.6589 - loss: 0.7517
# Epoch 8/15
# 77/77 - 0s - 3ms/step - accuracy: 0.6641 - loss: 0.7226
# Epoch 9/15
# 77/77 - 0s - 3ms/step - accuracy: 0.6602 - loss: 0.7103
# Epoch 10/15
# 77/77 - 0s - 4ms/step - accuracy: 0.6810 - loss: 0.6837
# Epoch 11/15
# 77/77 - 0s - 4ms/step - accuracy: 0.6549 - loss: 0.6850
# Epoch 12/15
# 77/77 - 0s - 4ms/step - accuracy: 0.6693 - loss: 0.6660
# Epoch 13/15
# 77/77 - 0s - 2ms/step - accuracy: 0.6836 - loss: 0.6492
# Epoch 14/15
# 77/77 - 0s - 2ms/step - accuracy: 0.6797 - loss: 0.6410
# ...

# %%
#Evaluate Model
score = model.evaluate(x,y)
print(model.metrics_names[1], score[1]*100)
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6726 - loss: 0.6432
# compile_metrics 67.1875

# %%
predictions = model.predict(x)
predictions
# Out:
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[4.60030138e-01],
#        [2.84810930e-01],
#        [9.25985992e-01],
#        [1.07463069e-01],
#        [9.81500804e-01],
#        [6.30205870e-01],
#        [4.74754512e-01],
#        [9.43480849e-01],
#        [9.24390912e-01],
#        [4.96365070e-01],
#        [5.01642823e-01],
#        [8.97309601e-01],
#        [6.41472757e-01],
#        [9.70389664e-01],
#        [7.85448730e-01],
#        [8.31222892e-01],
#        [5.68701252e-02],
#        [6.28692806e-01],
#        [9.61675882e-01],
#        [2.14121133e-01],
#        [6.22333810e-02],
#        [3.89772117e-01],
#        [8.74252617e-01],
#        [5.81836760e-01],
#        [3.57062072e-01],
#        [5.87998033e-01],
#        [7.07616210e-01],
#        [1.94419309e-01],
#        [1.19502448e-01],
#        [4.96963024e-01],
#        [1.89071298e-01],
#        [4.66712594e-01],
#        [1.21116832e-01],
#        [4.91362900e-01],
#        [4.98566806e-01],
# ...
